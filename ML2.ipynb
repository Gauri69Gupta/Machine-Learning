# %%
import math
import numpy as np
print("Question-1")
x=np.random.random((10,2))
print(x)
mn=print(np.mean(list(x)))
print('*'*20)
print("Question-2")
y=np.random.random((20,1))
print(y)
var=np.var(y)
print("variance is",var)
sd=np.std(y)
print("standard deviation is",sd)
print('*'*20)
print("Question-3")
a=np.random.random((10,20))
print(a)
b=np.random.random((20,25))
print(b)
c=np.matmul(a,b)
print("multiplication is matrices is",c)
d=np.sum(c)
print("sum of the matrix element is",d)
print('*'*20)
print("Question-4")
a=np.random.randint(10,size=(10,1))
def f(x):
    return(1/1+math.exp(-x))
arr=np.array(list(map(f,a)))
print(arr)
# Out:
# Question-1
# [[0.49838373 0.19910942]
#  [0.46660591 0.45005252]
#  [0.46623021 0.86836705]
#  [0.38665906 0.92355261]
#  [0.09664997 0.17305852]
#  [0.18692529 0.68840437]
#  [0.91318509 0.09398138]
#  [0.89079579 0.23700737]
#  [0.64197178 0.64105417]
#  [0.61427664 0.72471379]]
# 0.5080492337116824
# ********************
# Question-2
# [[4.52693517e-03]
#  [7.29647850e-01]
#  [9.40724340e-01]
#  [6.58841146e-01]
#  [7.27855124e-01]
#  [3.42334649e-01]
#  [3.04661389e-01]
#  [1.65646196e-01]
#  [1.50936033e-01]
#  [7.05345501e-01]
#  [7.63674666e-01]
#  [3.04451334e-01]
#  [5.41923952e-04]
#  [9.03054165e-01]
#  [7.65043821e-01]
#  [5.01241185e-01]
#  [9.80431293e-01]
#  [4.63795117e-02]
#  [9.17746559e-01]
#  [9.30487118e-01]]
# variance is 0.11295997415174792
# standard deviation is 0.3360951861478351
# ********************
# Question-3
# [[0.12115836 0.94959428 0.02967629 0.7843724  0.0658977  0.69399038
#   0.05601946 0.15222583 0.64077998 0.53366228 0.2144758  0.4935089
# ...
